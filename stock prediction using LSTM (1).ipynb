# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('c:\\Users\\Bhagya sri\\Downloads\\GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
# Assuming 'google_stock_data' is the DataFrame containing the stock data

plt.figure(figsize=(20, 7))

# First subplot
plt.subplot(1, 2, 1)
plt.plot(google_stock_data['open'], label='Open', color='green')
plt.xlabel('Date', size=15)
plt.ylabel('Price', size=15)
plt.legend()

# Second subplot
plt.subplot(1, 2, 2)
plt.plot(google_stock_data['close'], label='Close', color='red')
plt.xlabel('Date', size=15)
plt.ylabel('Price', size=15)
plt.legend()

plt.show()

# %%
#data preprocessing
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)
google_stock_data.shape
# Out:
# (1258, 2)

# %%
# creating training dataset
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
# creating LSTM MODEL
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 4s 42ms/step - loss: 0.0074 - mean_absolute_error: 0.0612 - val_loss: 0.0229 - val_mean_absolute_error: 0.1249
# Epoch 2/80
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0010 - mean_absolute_error: 0.0250 - val_loss: 0.0182 - val_mean_absolute_error: 0.1133
# Epoch 3/80
# 30/30 [==============================] - 1s 25ms/step - loss: 6.0485e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0100 - val_mean_absolute_error: 0.0810
# Epoch 4/80
# 30/30 [==============================] - 1s 27ms/step - loss: 6.0332e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0096 - val_mean_absolute_error: 0.0799
# Epoch 5/80
# 30/30 [==============================] - 1s 26ms/step - loss: 5.5896e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0082 - val_mean_absolute_error: 0.0737
# Epoch 6/80
# 30/30 [==============================] - 1s 26ms/step - loss: 5.1794e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0071 - val_mean_absolute_error: 0.0689
# Epoch 7/80
# 30/30 [==============================] - 1s 27ms/step - loss: 4.8988e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0061 - val_mean_absolute_error: 0.0639
# Epoch 8/80
# 30/30 [==============================] - 1s 26ms/step - loss: 4.9445e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0054 - val_mean_absolute_error: 0.0600
# Epoch 9/80
# 30/30 [==============================] - 1s 26ms/step - loss: 4.7968e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0035 - val_mean_absolute_error: 0.0471
# Epoch 10/80
# 30/30 [==============================] - 1s 25ms/step - loss: 4.2287e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0040 - val_mean_absolute_error: 0.0517
# Epoch 11/80
# 30/30 [==============================] - 1s 24ms/step - loss: 3.9286e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0053 - val_mean_absolute_error: 0.0616
# Epoch 12/80
# 30/30 [==============================] - 1s 25ms/step - loss: 3.7875e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0049 - val_mean_absolute_error: 0.0592
# Epoch 13/80
# 30/30 [==============================] - 1s 24ms/step - loss: 3.9104e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0060 - val_mean_absolute_error: 0.0647
# Epoch 14/80
# 30/30 [==============================] - 1s 24ms/step - loss: 3.5351e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0055 - val_mean_absolute_error: 0.0625
# Epoch 15/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.4474e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0065 - val_mean_absolute_error: 0.0686
# Epoch 16/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.1201e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0056 - val_mean_absolute_error: 0.0623
# Epoch 17/80
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1454e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 18/80
# 30/30 [==============================] - 1s 24ms/step - loss: 3.1147e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0040 - val_mean_absolute_error: 0.0511
# Epoch 19/80
# 30/30 [==============================] - 1s 25ms/step - loss: 3.2580e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0041 - val_mean_absolute_error: 0.0517
# Epoch 20/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.9174e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0063 - val_mean_absolute_error: 0.0665
# Epoch 21/80
# 30/30 [==============================] - 1s 25ms/step - loss: 2.9522e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0029 - val_mean_absolute_error: 0.0429
# Epoch 22/80
# 30/30 [==============================] - 1s 25ms/step - loss: 2.8129e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# Epoch 23/80
# 30/30 [==============================] - 1s 29ms/step - loss: 2.7973e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0036 - val_mean_absolute_error: 0.0487
# Epoch 24/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.8861e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0027 - val_mean_absolute_error: 0.0406
# Epoch 25/80
# 30/30 [==============================] - 1s 34ms/step - loss: 2.8194e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0033 - val_mean_absolute_error: 0.0456
# Epoch 26/80
# 30/30 [==============================] - 1s 36ms/step - loss: 2.8276e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0023 - val_mean_absolute_error: 0.0372
# Epoch 27/80
# 30/30 [==============================] - 1s 35ms/step - loss: 3.1240e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 28/80
# 30/30 [==============================] - 1s 34ms/step - loss: 2.6887e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0038 - val_mean_absolute_error: 0.0500
# Epoch 29/80
# 30/30 [==============================] - 1s 34ms/step - loss: 2.6714e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0059 - val_mean_absolute_error: 0.0661
# Epoch 30/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.4505e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0027 - val_mean_absolute_error: 0.0422
# Epoch 31/80
# 30/30 [==============================] - 1s 34ms/step - loss: 2.4740e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0054 - val_mean_absolute_error: 0.0618
# Epoch 32/80
# 30/30 [==============================] - 1s 32ms/step - loss: 2.4681e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0046 - val_mean_absolute_error: 0.0559
# Epoch 33/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.4719e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0021 - val_mean_absolute_error: 0.0358
# Epoch 34/80
# 30/30 [==============================] - 1s 34ms/step - loss: 2.5208e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0039 - val_mean_absolute_error: 0.0515
# Epoch 35/80
# 30/30 [==============================] - 1s 35ms/step - loss: 2.4622e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 36/80
# 30/30 [==============================] - 1s 32ms/step - loss: 2.3453e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0042 - val_mean_absolute_error: 0.0537
# Epoch 37/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.1933e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0029 - val_mean_absolute_error: 0.0430
# Epoch 38/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.4725e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0038 - val_mean_absolute_error: 0.0495
# Epoch 39/80
# 30/30 [==============================] - 1s 35ms/step - loss: 2.2280e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0036 - val_mean_absolute_error: 0.0505
# Epoch 40/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.2423e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0044 - val_mean_absolute_error: 0.0561
# Epoch 41/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.3562e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0056 - val_mean_absolute_error: 0.0658
# Epoch 42/80
# 30/30 [==============================] - 1s 35ms/step - loss: 2.2602e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0028 - val_mean_absolute_error: 0.0440
# Epoch 43/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.7084e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 44/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.9361e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 45/80
# 30/30 [==============================] - 1s 32ms/step - loss: 2.0130e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0027 - val_mean_absolute_error: 0.0400
# Epoch 46/80
# 30/30 [==============================] - 1s 32ms/step - loss: 2.1009e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0072 - val_mean_absolute_error: 0.0733
# Epoch 47/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.9076e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0033 - val_mean_absolute_error: 0.0453
# Epoch 48/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.9519e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 49/80
# 30/30 [==============================] - 1s 34ms/step - loss: 2.0834e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0030 - val_mean_absolute_error: 0.0448
# Epoch 50/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.8522e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0030 - val_mean_absolute_error: 0.0457
# Epoch 51/80
# 30/30 [==============================] - 1s 32ms/step - loss: 1.6899e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0018 - val_mean_absolute_error: 0.0342
# Epoch 52/80
# 30/30 [==============================] - 1s 32ms/step - loss: 1.8349e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0016 - val_mean_absolute_error: 0.0325
# Epoch 53/80
# 30/30 [==============================] - 1s 32ms/step - loss: 1.7608e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0023 - val_mean_absolute_error: 0.0394
# Epoch 54/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.5900e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0025 - val_mean_absolute_error: 0.0411
# Epoch 55/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.6508e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0035 - val_mean_absolute_error: 0.0490
# Epoch 56/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.7688e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0037 - val_mean_absolute_error: 0.0518
# Epoch 57/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.6210e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0055 - val_mean_absolute_error: 0.0647
# Epoch 58/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.6262e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0054 - val_mean_absolute_error: 0.0629
# Epoch 59/80
# 30/30 [==============================] - 1s 32ms/step - loss: 1.5998e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0038 - val_mean_absolute_error: 0.0516
# Epoch 60/80
# 30/30 [==============================] - 1s 32ms/step - loss: 1.7439e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0041 - val_mean_absolute_error: 0.0542
# Epoch 61/80
# 30/30 [==============================] - 1s 32ms/step - loss: 1.4773e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0029 - val_mean_absolute_error: 0.0444
# Epoch 62/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.5875e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0036 - val_mean_absolute_error: 0.0504
# Epoch 63/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.4784e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0031 - val_mean_absolute_error: 0.0475
# Epoch 64/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.4106e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0057 - val_mean_absolute_error: 0.0651
# Epoch 65/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.5291e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0027 - val_mean_absolute_error: 0.0431
# Epoch 66/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.4880e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0316
# Epoch 67/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.7291e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0034 - val_mean_absolute_error: 0.0499
# Epoch 68/80
# 30/30 [==============================] - 1s 35ms/step - loss: 1.3292e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0367
# Epoch 69/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.3260e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 70/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.6354e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0013 - val_mean_absolute_error: 0.0298
# Epoch 71/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.4463e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0018 - val_mean_absolute_error: 0.0353
# Epoch 72/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.5108e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0021 - val_mean_absolute_error: 0.0387
# Epoch 73/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.5363e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 74/80
# 30/30 [==============================] - 1s 35ms/step - loss: 1.3446e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0034 - val_mean_absolute_error: 0.0502
# Epoch 75/80
# 30/30 [==============================] - 1s 36ms/step - loss: 1.3532e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0016 - val_mean_absolute_error: 0.0327
# Epoch 76/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.2776e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0324
# Epoch 77/80
# 30/30 [==============================] - 1s 40ms/step - loss: 1.3696e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0032 - val_mean_absolute_error: 0.0489
# Epoch 78/80
# 30/30 [==============================] - 1s 35ms/step - loss: 1.5507e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 79/80
# 30/30 [==============================] - 1s 34ms/step - loss: 1.2833e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0015 - val_mean_absolute_error: 0.0314
# Epoch 80/80
# 30/30 [==============================] - 1s 33ms/step - loss: 1.4327e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0038 - val_mean_absolute_error: 0.0538

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 7ms/step
# array([[0.47122446, 0.47404155],
#        [0.47708115, 0.4793668 ],
#        [0.483904  , 0.48588902],
#        [0.5016556 , 0.50377566],
#        [0.51025176, 0.511182  ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1544.6124, 1546.8202],
#        [1555.4702, 1556.6897],
#        [1568.1193, 1568.7776],
#        [1601.0293, 1601.9276],
#        [1616.966 , 1615.654 ]], dtype=float32)

# %%
# data visualizing and actual data
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1544.612427      1546.820190
# 2020-08-25  1582.07  1608.22     1555.470215      1556.689697
# 2020-08-26  1608.00  1652.38     1568.119263      1568.777588
# 2020-08-27  1653.68  1634.33     1601.029297      1601.927612
# 2020-08-28  1633.49  1644.41     1616.965942      1615.654053

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,
                        index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
# C:\Users\Bhagya Sri\AppData\Local\Temp\ipykernel_26120\2970346174.py:4: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# C:\Users\Bhagya Sri\AppData\Local\Temp\ipykernel_26120\2970346174.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2340.221924      2297.730957
# 2021-06-10  2494.01  2521.60     2350.330811      2305.945312
# 2021-06-11  2524.92  2513.93     2365.927979      2321.752686
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\Bhagya Sri\AppData\Local\Temp\ipykernel_26120\4155468105.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\Bhagya Sri\AppData\Local\Temp\ipykernel_26120\548185773.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()
